# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
plt.rcParams['font.family'] = 'Times New Roman'
# For changed, smote
data1 = {
    'adb': [0.7272270767653753],
    'rf_adb': [0.7402982526488834],
    'rf_lr': [0.7926840504845345],
    'rf_xgb': [0.7796767118765175],
    'gbm': [0.7911228297061447],
    'knn': [0.7968288349955817],
    'lr': [0.513447289477283],
    'mlp': [0.5548830767512897],
    'nb': [0.5196663475408598],
    'rf': [0.7866123992471811],
    'svm': [0.49525738507830724],
    'xgb': [0.778864747808991]
}
# For unchanged, norm
data2 = {
    'adb': [0.6158838199045175],
    'rf_adb': [0.6163243924554926],
    'rf_lr': [0.5987410592633335],
    'rf_xgb': [0.6371552741910314],
    'gbm': [0.6009381253525923],
    'knn': [0.6060553886665396],
    'lr': [0.6032426236533015],
    'mlp': [0.5991309203279344],
    'nb': [0.6050399400101493],
    'rf': [0.5996384976897868],
    'svm': [0.5996010006137718],
    'xgb': [0.5938165981648578]
}
# For changed, smote
data3 = {
    'adb': [0.6093368436980083],
    'rf_adb': [0.6260458376717377],
    'rf_lr': [0.6047669740888466],
    'rf_xgb': [0.6294369144207204],
    'gbm': [0.6417159387153525],
    'knn': [0.6097727396975494],
    'lr': [0.6544143075093529],
    'mlp': [0.5685621166334363],
    'nb': [0.6065298626745411],
    'rf': [0.6711924737795317],
    'svm': [0.591990175685617],
    'xgb': [0.6010100362645525]
}

df1 = pd.DataFrame.from_dict(data1, orient='index', columns=['Value']) * 100
df2 = pd.DataFrame.from_dict(data2, orient='index', columns=['Value']) * 100
df3 = pd.DataFrame.from_dict(data3, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df3, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Precisions of models (CV)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Precision (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('precisions(cv).png', dpi=300)

# %%
# For changed, smote
data4 = {
    'adb': [0.7432515421880451],
    'rf_adb': [0.7232519175613376],
    'rf_lr': [0.7737496542060572],
    'rf_xgb': [0.79389608950925],
    'gbm': [0.7907781809174098],
    'knn': [0.823604763542844],
    'lr': [0.5385269828613345],
    'mlp': [0.6034568402989456],
    'nb': [0.5032632258659656],
    'rf': [0.7610294839441402],
    'svm': [0.49967425705551505],
    'xgb': [0.7836139169472504]
}
# For unchanged, norm
data5 = {
    'adb': [0.45607919687674287],
    'rf_adb': [0.4430621014082619],
    'rf_lr': [0.4461845344198285],
    'rf_xgb': [0.47958154035502104],
    'gbm': [0.6063575770892844],
    'knn': [0.3810919540229885],
    'lr': [0.45203619909502263],
    'mlp': [0.4285386240470286],
    'nb': [0.41336860670194003],
    'rf': [0.3939761471598949],
    'svm': [0.4655980090762699],
    'xgb': [0.40322420634920636]
}
# For changed, weighted
data6 = {
    'adb': [0.48932773109243705],
    'rf_adb': [0.3965908249719042],
    'rf_lr': [0.4295893719806763],
    'rf_xgb': [0.5981239903891837],
    'gbm': [0.5974544778892605],
    'knn': [0.38024575653441633],
    'lr': [0.4498861962779488],
    'mlp': [0.48529657477025895],
    'nb': [0.43714441586782016],
    'rf': [0.44773982056590755],
    'svm': [0.4574960127591707],
    'xgb': [0.43241968759210136]
}

df4 = pd.DataFrame.from_dict(data4, orient='index', columns=['Value']) * 100
df5 = pd.DataFrame.from_dict(data5, orient='index', columns=['Value']) * 100
df6 = pd.DataFrame.from_dict(data6, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df4, df5, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df6, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Precisions of models (test)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Precision (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('precisions(test).png', dpi=300)
