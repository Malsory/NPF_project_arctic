# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'Times New Roman'
# For changed, smote
data1 = {
    'adb': [0.7258064516129032],
    'rf_adb': [0.739247311827957],
    'rf_lr': [0.7860215053763441],
    'rf_xgb': [0.7801075268817204],
    'gbm': [0.7908602150537634],
    'knn': [0.7913978494623656],
    'lr': [0.5198924731182796],
    'mlp': [0.5516129032258065],
    'nb': [0.5166666666666666],
    'rf': [0.7849462365591398],
    'svm': [0.489247311827957],
    'xgb': [0.7779569892473118]
}
# For unchanged, norm
data2 = {
    'adb': [0.6086837075967511],
    'rf_adb': [0.5891304347826087],
    'rf_lr': [0.6917462971810797],
    'rf_xgb': [0.6667821309125657],
    'gbm': [0.6621954132823697],
    'knn': [0.695090778786431],
    'lr': [0.6994983277591973],
    'mlp': [0.6851528905876731],
    'nb': [0.6885212613473483],
    'rf': [0.677615862398471],
    'svm': [0.6840301003344482],
    'xgb': [0.6624343048256092]
}
# For changed, weighted
data3 = {
    'adb': [0.5880315336837076],
    'rf_adb': [0.6010152890587673],
    'rf_lr': [0.6972527472527472],
    'rf_xgb': [0.6622909698996655],
    'gbm': [0.6884854276158624],
    'knn': [0.675370281892021],
    'lr': [0.5048614429049212],
    'mlp': [0.6667224080267559],
    'nb': [0.6929049211657907],
    'rf': [0.6612040133779264],
    'svm': [0.6905637840420449],
    'xgb': [0.6742116579073101]
}

df1 = pd.DataFrame.from_dict(data1, orient='index', columns=['Value']) * 100
df2 = pd.DataFrame.from_dict(data2, orient='index', columns=['Value']) * 100
df3 = pd.DataFrame.from_dict(data3, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df3, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Recalls of models (CV)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Recall (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('recalls(cv).png', dpi=300)

# %%
# For changed, smote
data4 = {
    'adb': [0.7419354838709676],
    'rf_adb': [0.7225806451612903],
    'rf_lr': [0.7698924731182796],
    'rf_xgb': [0.49863754758565415],
    'gbm': [0.7904291630128298],
    'knn': [0.8249743395059124],
    'lr': [0.5483870967741936],
    'mlp': [0.42618045815801775],
    'nb': [0.4682051282051282],
    'rf': [0.4750183663928405],
    'svm': [0.5290322580645161],
    'xgb': [0.7849462365591396]
}
# For unchanged, norm
data5 = {
    'adb': [0.4498163360715955],
    'rf_adb': [0.436475656181126],
    'rf_lr': [0.48008415147265077],
    'rf_xgb': [0.4235423762772991],
    'gbm': [0.4525039592847148],
    'knn': [0.4139433551198257],
    'lr': [0.46185133239831694],
    'mlp': [0.4532491818606825],
    'nb': [0.4883673365035537],
    'rf': [0.41271622253389434],
    'svm': [0.3660589060308555],
    'xgb': [0.42211313697989716]
}
# For changed, weighted
data6 = {
    'adb': [0.5003372737594337],
    'rf_adb': [0.3945067788686302],
    'rf_lr': [0.47283777466105653],
    'rf_xgb': [0.49863754758565415],
    'gbm': [0.47804989464735986],
    'knn': [0.39614695340501793],
    'lr': [0.4880551659654044],
    'mlp': [0.42618045815801775],
    'nb': [0.4682051282051282],
    'rf': [0.4750183663928405],
    'svm': [0.389387564282375],
    'xgb': [0.3926901756495025]
}

df4 = pd.DataFrame.from_dict(data4, orient='index', columns=['Value']) * 100
df5 = pd.DataFrame.from_dict(data5, orient='index', columns=['Value']) * 100
df6 = pd.DataFrame.from_dict(data6, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df4, df5, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df6, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Recalls of models (test)', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Recall (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('recalls(test).png', dpi=300)
