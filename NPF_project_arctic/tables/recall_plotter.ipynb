# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
plt.rcParams['font.family'] = 'Times New Roman'
# For unchanged, normal
data1 = {
    'adb': [0.3877241845701598],
    'rf_adb': [0.4217002901639124],
    'rf_lr': [0.39540869218500796],
    'rf_xgb': [0.43303584160937103],
    'gbm': [0.3665628232164778],
    'knn': [0.3842879470628831],
    'lr': [0.3592168534080299],
    'mlp': [0.4393639586061177],
    'nb': [0.548078038232837],
    'rf': [0.3638905284601879],
    'svm': [0.2988529770882712],
    'xgb': [0.3457994227994228]
}
# For changed, test
data2 = {
    'adb': [0.3877241845701598],
    'rf_adb': [0.39672268907563024],
    'rf_lr': [0.360994005994006],
    'rf_xgb': [0.3985996524115719],
    'gbm': [0.36568333713070555],
    'knn': [0.29910523343932954],
    'lr': [0.7381953781512605],
    'mlp': [0.24478124104110321],
    'nb': [0.5538718745023092],
    'rf': [0.6251180033416875],
    'svm': [0.25517929521160104],
    'xgb': [0.4141901227427543]
}
# For changed, smote
data3 = {
    'adb': [0.7745259116765468],
    'rf_adb': [0.7908907761057082],
    'rf_lr': [0.8814277298654797],
    'rf_xgb': [0.8565976662865982],
    'gbm': [0.8546341033106648],
    'knn': [0.9112271128763871],
    'lr': [0.7268597319179718],
    'mlp': [0.7858005189738066],
    'nb': [0.7676760872871101],
    'rf': [0.859372387619723],
    'svm': [0.7546794063285818],
    'xgb': [0.838298008593758]
}

df1 = pd.DataFrame.from_dict(data3, orient='index', columns=['Value']) * 100
df2 = pd.DataFrame.from_dict(data1, orient='index', columns=['Value']) * 100
df3 = pd.DataFrame.from_dict(data2, orient='index', columns=['Value']) * 100
# Merge the two DataFrames on common index (names)
merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.merge(merged_df, df3, left_index=True, right_index=True)
merged_df['models'] = merged_df.index

# Plotting side-by-side bar plots
plt.figure()
merged_df.plot(kind='bar', width=0.9)
plt.title('Recalls of models for NPF days', fontsize=40)
plt.xlabel('Models', fontsize=30)
plt.ylabel('Recall (%)', fontsize=30)
plt.xticks(rotation=45)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)
plt.legend(['SMOTE', 'normal', "weighted"], loc='upper right', fontsize=15)

fig = plt.gcf()
fig.set_size_inches(25, 15)

plt.savefig('recalls.png', dpi=300)
