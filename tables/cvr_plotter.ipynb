    'xgb': [0.79032258, 0.74731183, 0.77956989, 0.76344086, 0.78494624, 0.77956989, 0.86021505, 0.77956989, 0.77419355, 0.76344086]
}

combined_values = [value for values in data.values() for value in values]
combined_values2 = [value for values in data2.values() for value in values]
combined_values3 = [value for values in data3.values() for value in values]
df1 = pd.DataFrame({'Model': [key for key in data.keys() for _ in range(len(data[key]))],'Accuracy (%)': combined_values})
df2 = pd.DataFrame({'Model': [key for key in data2.keys() for _ in range(len(data2[key]))],'Precision (%)': combined_values2})
df3 = pd.DataFrame({'Model': [key for key in data3.keys() for _ in range(len(data3[key]))],'Recall (%)': combined_values3})

merged_df = pd.merge(df1, df2, on='Model')
merged_df = pd.merge(merged_df, df3, on='Model')

merged_melted = pd.melt(merged_df, id_vars='Model', var_name='Metric', value_name='Percentage')
# Create a boxplot
plt.figure(figsize=(20, 10))
sns.boxplot(x='Model', y='Percentage', hue='Metric', data=merged_melted)
plt.title('Cross-Validation Results', fontsize=30)
plt.xlabel('Model', fontsize=20)
plt.ylabel('Percentage', fontsize=20)
plt.xticks(rotation=45, ha='right', fontsize=20)
plt.yticks(fontsize=20)
plt.legend(title='Metric', fontsize=12, title_fontsize=12)
plt.tight_layout()
plt.savefig('cv_boxplots_side_by_side.png', dpi=300)
plt.show()

# Calculate highest, lowest, and average values for each column
column_stats = df.describe().transpose()[['min', 'mean', 'max']]

with open('cv_accuracy.txt', 'w') as file:
    sys.stdout = file
    # Print the results for each column
    for column in column_stats.index:
        highest_value = column_stats.loc[column, 'max']
        lowest_value = column_stats.loc[column, 'min']
        average_value = column_stats.loc[column, 'mean']
        
        print(f'Column: {column}')
        print(f'Highest Value: {highest_value:.4f}')
        print(f'Lowest Value: {lowest_value:.4f}')
        print(f'Average Value: {average_value:.4f}\n')
    # Reset stdout back to the console
    sys.stdout = sys.__stdout__
    
with open('cv_precision.txt', 'w') as file:
    sys.stdout = file
    # Print the results for each column
    for column in column_stats.index:
        highest_value = column_stats.loc[column, 'max']
        lowest_value = column_stats.loc[column, 'min']
        average_value = column_stats.loc[column, 'mean']
        
        print(f'Column: {column}')
        print(f'Highest Value: {highest_value:.4f}')
        print(f'Lowest Value: {lowest_value:.4f}')
        print(f'Average Value: {average_value:.4f}\n')
    # Reset stdout back to the console
    sys.stdout = sys.__stdout__
    
with open('cv_recall.txt', 'w') as file:
    sys.stdout = file
    # Print the results for each column
    for column in column_stats.index:
        highest_value = column_stats.loc[column, 'max']
        lowest_value = column_stats.loc[column, 'min']
        average_value = column_stats.loc[column, 'mean']
        
        print(f'Column: {column}')
        print(f'Highest Value: {highest_value:.4f}')
        print(f'Lowest Value: {lowest_value:.4f}')
        print(f'Average Value: {average_value:.4f}\n')
    # Reset stdout back to the console
    sys.stdout = sys.__stdout__
